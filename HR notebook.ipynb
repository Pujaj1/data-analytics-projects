# %%
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# !pip install statsmodels
# !pip install pandas
# !pip install scipy
# !pip install scikit_learn
# !pip install projectpro

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
import pandas as pd
df=pd.read_csv('HR_Analytics.csv')
print(df)
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1465   RM412   60      55+        No      Travel_Rarely        422
# 1466   RM428   60      55+        No  Travel_Frequently       1499
# 1467   RM537   60      55+        No      Travel_Rarely       1179
# 1468   RM880   60      55+        No      Travel_Rarely        696
# 1469  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
df.shape
# Out:
# (1470, 38)

# %%
df.head(10)
# Out:
#     EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0   RM297   18    18-25       Yes      Travel_Rarely        230
# 1   RM302   18    18-25        No      Travel_Rarely        812
# 2   RM458   18    18-25       Yes  Travel_Frequently       1306
# 3   RM728   18    18-25        No         Non-Travel        287
# 4   RM829   18    18-25       Yes         Non-Travel        247
# 5   RM973   18    18-25        No         Non-Travel       1124
# 6  RM1154   18    18-25       Yes  Travel_Frequently        544
# 7  RM1312   18    18-25        No         Non-Travel       1431
# 8   RM128   19    18-25       Yes      Travel_Rarely        528
# 9   RM150   19    18-25        No      Travel_Rarely       1181
#
#                Department  DistanceFromHome  Education EducationField  ...  \
# 0  Research & Development                 3          3  Life Sciences  ...
# 1                   Sales                10          3        Medical  ...
# ...

# %%
df.tail(10)
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 1460   RM233   59      55+        No      Travel_Rarely        818
# 1461   RM744   59      55+        No      Travel_Rarely        715
# 1462   RM759   59      55+        No      Travel_Rarely       1089
# 1463   RM898   59      55+        No      Travel_Rarely        326
# 1464   RM920   59      55+        No      Travel_Rarely       1429
# 1465   RM412   60      55+        No      Travel_Rarely        422
# 1466   RM428   60      55+        No  Travel_Frequently       1499
# 1467   RM537   60      55+        No      Travel_Rarely       1179
# 1468   RM880   60      55+        No      Travel_Rarely        696
# 1469  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1460         Human Resources                 6          2           Medical
# ...

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df = df.drop('EmpID', axis=1)

# %%
df = df.drop('AgeGroup', axis=1)

# %%
df = df.drop('SalarySlab', axis=1)

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
attrition_count=pd.DataFrame(df['Attrition'].value_counts()) #counts of no and yes in attrition column
attrition_count
# Out:
#      Attrition
# No        1233
# Yes        237

# %%
plt.pie(attrition_count['Attrition'], labels=['Yes', 'No'], explode=(0, 0))  # can also put 0.1,.0.2...
# Out:
# ([<matplotlib.patches.Wedge at 0x2a6d72d1e90>,
# ...
#  [Text(-0.9618916732177651, 0.5336332157899547, 'Yes'),
#   Text(0.961891673217765, -0.5336332157899547, 'No')])

# %%
sns.countplot(x='Attrition', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
df = df.drop('EmployeeCount', axis=1)
df = df.drop('EmployeeNumber', axis=1)

# %%
attrition_dummies=pd.get_dummies(df['Attrition'])  # to convert string to integers and concate this in dataset 
attrition_dummies.head()
# Out:
#    No  Yes
# 0   0    1
# 1   1    0
# 2   0    1
# 3   1    0
# 4   0    1

# %%
df=pd.concat([df, attrition_dummies], axis=1)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   18       Yes      Travel_Rarely        230  Research & Development
# 1   18        No      Travel_Rarely        812                   Sales
# 2   18       Yes  Travel_Frequently       1306                   Sales
# 3   18        No         Non-Travel        287  Research & Development
# 4   18       Yes         Non-Travel        247  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 3          3  Life Sciences                        3
# 1                10          3        Medical                        4
# 2                 5          3      Marketing                        2
# 3                 5          2  Life Sciences                        2
# 4                 8          1        Medical                        3
#
#    Gender  ...  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df= df.drop(['Attrition', 'No'], axis=1)
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   18      Travel_Rarely        230  Research & Development
# 1   18      Travel_Rarely        812                   Sales
# 2   18  Travel_Frequently       1306                   Sales
# 3   18         Non-Travel        287  Research & Development
# 4   18         Non-Travel        247  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 3          3  Life Sciences                        3
# 1                10          3        Medical                        4
# 2                 5          3      Marketing                        2
# 3                 5          2  Life Sciences                        2
# 4                 8          1        Medical                        3
#
#    Gender  HourlyRate  ...  StandardHours  StockOptionLevel TotalWorkingYears  \
# 0    Male          54  ...             80                 0                 0
# ...

# %%
from scipy import stats
print("Minimum values: ",df.min())
print("Maximum values: ",df.max())
print("Median values: ",df.median())
numeric_cols = df.select_dtypes(include=[np.number]).columns
z_scores = stats.zscore(df[numeric_cols])

print(z_scores)
# Out:
# Minimum values:  Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# ...

# %%
z_df = pd.DataFrame(z_scores, columns=df.columns)
plt.figure(figsize=(30, 10))
# Plot the z score distribution for each feature
sns.boxplot(data=z_df)
plt.title("Z score distribution of HR Analytics")
plt.show()

# %%
sns.barplot(x='Gender', y='Yes', data=df) # to know either male or female are attrited
# Out:
# <Axes: xlabel='Gender', ylabel='Yes'>

# %%
sns.barplot(x='Department', y='Yes', data=df) # to know from which department attrition was done
# Out:
# <Axes: xlabel='Department', ylabel='Yes'>

# %%
sns.barplot(x='BusinessTravel', y='Yes', data=df) # to know which category are attrited
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='Yes'>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.drop(['Age', 'JobLevel'], axis=1)
# Out:
#          BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 0         Travel_Rarely        230  Research & Development                 3
# 1         Travel_Rarely        812                   Sales                10
# 2     Travel_Frequently       1306                   Sales                 5
# 3            Non-Travel        287  Research & Development                 5
# 4            Non-Travel        247  Research & Development                 8
# ...                 ...        ...                     ...               ...
# 1465      Travel_Rarely        422  Research & Development                 7
# 1466  Travel_Frequently       1499                   Sales                28
# 1467      Travel_Rarely       1179                   Sales                16
# 1468      Travel_Rarely        696                   Sales                 7
# 1469      Travel_Rarely        370  Research & Development                 1
#
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## #Convert String Columns Into Integers

# %%
from sklearn.preprocessing import LabelEncoder
for column in df.columns:
    if df[column].dtype==np.number:    #if column is integer it will continue
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])# if my column is string then it will convert to label encoder so they data can be feeded into model

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
#rf= RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)

# %%
x=df.drop(['Yes'], axis=1) #remove yes column from data part because it is input part
y=df['Yes'] # it is the output part to predict attrition

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3)

# %%
x_train.head()
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 318    11               2        160           0                 5          0
# 1104   25               1        431           2                14          2
# 1350   34               2        141           1                 2          2
# 1363   34               0        306           2                28          3
# 1361   34               1        142           1                27          1
#
#       EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 318                3                        3       1          57  ...
# 1104               1                        3       1          17  ...
# 1350               3                        3       1           9  ...
# 1363               1                        0       1          10  ...
# 1361               3                        3       0          29  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
print(np.any(np.isnan(X)))
# Out:
# False

# %%
X = np.nan_to_num(X, nan=0.0)

# %%
rf.score(x_train, y_train)
# Out:
# 0.9776482021379981

# %% [markdown]
# # Predicting for x_test

# %%
pred= rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, pred)
# Out:
# 0.854875283446712
